# %%
from random import choice
word = choice(["monday","dragon","sticky","wicked","knights","laptop","zinger","pyjama","jacked","sudoku","blazed","quiver","detect","brazen","pickup"])

guessed = []
wrong = []

tries = 10;
print(" Guess the 6 letter word")
while tries > 0:

    out = ""
    for letter in word:
        if letter in guessed:
            out = out + letter
        else:
            out = out + "_"

    if out == word:
        break

    print("Guess the word:",out)
    print("chances left:",tries)

    guess = raw_input()

    if guess in guessed or guess in wrong:
        print('Already guessed', guess)
    elif guess in word:
        print("Correct!")
        guessed.append(guess)
    else:
        print("Wrong,Guess again!")
        tries = tries - 1
        wrong.append(guess)

    print("correctly guessed:",guessed)
    print("wrongly guessed:",wrong)

if tries:
    print("You guessed", word)
else:
    print("The word was", word)
    print("Try again next time!")
# Out:
#  Guess the 6 letter word
# ('Guess the word:', '______')
# ('chances left:', 10)
# y
# Wrong,Guess again!
# ('correctly guessed:', [])
# ('wrongly guessed:', ['y'])
# ('Guess the word:', '______')
# ('chances left:', 9)
# r
# Wrong,Guess again!
# ('correctly guessed:', [])
# ('wrongly guessed:', ['y', 'r'])
# ('Guess the word:', '______')
# ('chances left:', 8)
# a
# Correct!
# ('correctly guessed:', ['a'])
# ('wrongly guessed:', ['y', 'r'])
# ('Guess the word:', '_a____')
# ('chances left:', 8)
# y
# ('Already guessed', 'y')
# ('correctly guessed:', ['a'])
# ('wrongly guessed:', ['y', 'r'])
# ('Guess the word:', '_a____')
# ('chances left:', 8)
# l
# Wrong,Guess again!
# ('correctly guessed:', ['a'])
# ('wrongly guessed:', ['y', 'r', 'l'])
# ('Guess the word:', '_a____')
# ('chances left:', 7)
# v
# Wrong,Guess again!
# ('correctly guessed:', ['a'])
# ('wrongly guessed:', ['y', 'r', 'l', 'v'])
# ('Guess the word:', '_a____')
# ('chances left:', 6)
# h
# Wrong,Guess again!
# ...
